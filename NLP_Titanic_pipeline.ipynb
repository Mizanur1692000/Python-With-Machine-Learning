# %%
import pandas as pd
df = pd.read_csv('Titanic.csv')

# %%
df.shape
# Out:
# (889, 9)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
df = df.drop(['PassengerId','Embarked'],axis=1)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    Male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    Male  35.0      0      0   8.0500

# %%
df.corr()
s -  0 1 
c -  1 2 3
s(high) c(low)
s(1) c(1 okay)
# Out:
#   Cell In[10], line 2
#     s -  0 1
#            ^
# SyntaxError: invalid syntax

# %%
y=df['Survived']
df = df.drop(['Survived'],axis=1)
df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare
# 0       3    Male  22.0      1      0   7.2500
# 1       1  female  38.0      1      0  71.2833
# 2       3  female  26.0      0      0   7.9250
# 3       1  female  35.0      1      0  53.1000
# 4       3    Male  35.0      0      0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
sex_transformed = le.fit_transform(df['Sex'])
df['Sex']=sex_transformed
df.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare
# 0       3    0  22.0      1      0   7.2500
# 1       1    1  38.0      1      0  71.2833
# 2       3    1  26.0      0      0   7.9250
# 3       1    1  35.0      1      0  53.1000
# 4       3    0  35.0      0      0   8.0500

# %%
df.corr()
# Out:
#           Pclass       Sex       Age     SibSp     Parch      Fare
# Pclass  1.000000 -0.127741 -0.122449  0.081656  0.016824 -0.548193
# Sex    -0.127741  1.000000 -0.102014  0.116348  0.247508  0.179958
# Age    -0.122449 -0.102014  1.000000 -0.156777 -0.215191 -0.003307
# SibSp   0.081656  0.116348 -0.156777  1.000000  0.414542  0.160887
# Parch   0.016824  0.247508 -0.215191  0.414542  1.000000  0.217532
# Fare   -0.548193  0.179958 -0.003307  0.160887  0.217532  1.000000

# %%
df['Age'].values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 60.  , 54.  ,  2.  , 27.  ,
#        14.  ,  4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 60.  ,
#        31.  , 60.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 60.  ,
#        19.  , 60.  , 60.  , 40.  , 60.  , 60.  , 66.  , 28.  , 42.  ,
#        60.  , 21.  , 18.  , 14.  , 40.  , 27.  , 60.  ,  3.  , 19.  ,
#        60.  , 60.  , 60.  , 60.  , 18.  ,  7.  , 21.  , 49.  , 29.  ,
#        65.  , 60.  , 21.  , 28.5 ,  5.  , 11.  , 22.  , 45.  ,  4.  ,
#        60.  , 60.  , 29.  , 19.  , 17.  , 26.  , 32.  , 16.  , 21.  ,
#        26.  , 32.  , 25.  , 60.  , 60.  ,  0.83, 30.  , 22.  , 29.  ,
#        60.  , 28.  , 17.  , 33.  , 16.  , 60.  , 23.  , 24.  , 29.  ,
#        20.  , 46.  , 26.  , 59.  , 60.  , 71.  , 23.  , 34.  , 34.  ,
#        28.  , 60.  , 21.  , 33.  , 37.  , 28.  , 21.  , 60.  , 38.  ,
# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  889 non-null    int64
#  1   Sex     889 non-null    int32
#  2   Age     889 non-null    float64
#  3   SibSp   889 non-null    int64
#  4   Parch   889 non-null    int64
#  5   Fare    889 non-null    float64
# dtypes: float64(2), int32(1), int64(3)
# memory usage: 38.3 KB

# %%
df.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare
# 0       3    0  22.0      1      0   7.2500
# 1       1    1  38.0      1      0  71.2833
# 2       3    1  26.0      0      0   7.9250
# 3       1    1  35.0      1      0  53.1000
# 4       3    0  35.0      0      0   8.0500

# %%
x=df

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((711, 6), (178, 6), (711,), (178,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
standard_df_train = scaler.fit_transform(X_train)
standard_df_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for i in range(3,30,2):
      print('k = '+str(i))
      # train the model using the train data
      neigh = KNeighborsClassifier(n_neighbors=i)
      neigh.fit(standard_df_train, y_train)

      # predict using the trained model
      y_pred_train = neigh.predict(standard_df_train)
      y_pred_test = neigh.predict(standard_df_test)

      # Accuracy
      acc_train = accuracy_score(y_train, y_pred_train)
      print('Accuracy of training data',acc_train)
      acc_test = accuracy_score(y_test, y_pred_test)
      print('Accuracy of testing data',acc_test)
      print('-'*50)
      print('-'*50)
# Out:
# k = 3
# Accuracy of training data 0.8874824191279888
# Accuracy of testing data 0.8089887640449438
# --------------------------------------------------
# --------------------------------------------------
# k = 5
# Accuracy of training data 0.869198312236287
# Accuracy of testing data 0.7865168539325843
# --------------------------------------------------
# --------------------------------------------------
# k = 7
# Accuracy of training data 0.8452883263009845
# Accuracy of testing data 0.7921348314606742
# --------------------------------------------------
# --------------------------------------------------
# k = 9
# Accuracy of training data 0.8452883263009845
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------
# k = 11
# Accuracy of training data 0.8255977496483825
# Accuracy of testing data 0.7696629213483146
# --------------------------------------------------
# --------------------------------------------------
# k = 13
# Accuracy of training data 0.829817158931083
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------
# k = 15
# Accuracy of training data 0.8326300984528833
# Accuracy of testing data 0.7528089887640449
# --------------------------------------------------
# --------------------------------------------------
# k = 17
# Accuracy of training data 0.8326300984528833
# Accuracy of testing data 0.7528089887640449
# --------------------------------------------------
# --------------------------------------------------
# k = 19
# Accuracy of training data 0.8354430379746836
# Accuracy of testing data 0.7528089887640449
# --------------------------------------------------
# --------------------------------------------------
# k = 21
# Accuracy of training data 0.8255977496483825
# Accuracy of testing data 0.7696629213483146
# --------------------------------------------------
# --------------------------------------------------
# k = 23
# Accuracy of training data 0.829817158931083
# Accuracy of testing data 0.7528089887640449
# --------------------------------------------------
# --------------------------------------------------
# k = 25
# Accuracy of training data 0.8368495077355836
# Accuracy of testing data 0.7640449438202247
# --------------------------------------------------
# --------------------------------------------------
# k = 27
# Accuracy of training data 0.8270042194092827
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------
# k = 29
# Accuracy of training data 0.8340365682137834
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

list1 = [0.0001,0.001,0.01,0.1,1,10,100,1000,10000]
for i in list1:
      print(' alpha = '+str(i))
      # train the model using the train data
      bayes = GaussianNB(var_smoothing = i )
      bayes.fit(standard_df_train, y_train)

      # predict using the trained model
      y_pred_train = bayes.predict(standard_df_train)
      y_pred_test = bayes.predict(standard_df_test)

      # Accuracy
      acc_train = accuracy_score(y_train, y_pred_train)
      print('Accuracy of training data',acc_train)
      acc_test = accuracy_score(y_test, y_pred_test)
      print('Accuracy of testing data',acc_test)
      print('-'*50)
      print('-'*50)
# Out:
#  alpha = 0.0001
# Accuracy of training data 0.7960618846694796
# Accuracy of testing data 0.7640449438202247
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.001
# Accuracy of training data 0.7960618846694796
# Accuracy of testing data 0.7640449438202247
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.01
# Accuracy of training data 0.7974683544303798
# Accuracy of testing data 0.7640449438202247
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.1
# Accuracy of training data 0.7988748241912799
# Accuracy of testing data 0.7640449438202247
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 1
# Accuracy of training data 0.7876230661040787
# Accuracy of testing data 0.7752808988764045
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 10
# Accuracy of training data 0.6244725738396625
# Accuracy of testing data 0.6460674157303371
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 100
# Accuracy of training data 0.6146272855133614
# Accuracy of testing data 0.6292134831460674
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 1000
# Accuracy of training data 0.6146272855133614
# Accuracy of testing data 0.6292134831460674
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 10000
# Accuracy of training data 0.6146272855133614
# Accuracy of testing data 0.6292134831460674
# --------------------------------------------------
# --------------------------------------------------

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

list1 = [0.0001,0.001,0.01,0.1,1,10,100,1000,10000]
for i in list1:
      print(' alpha = '+str(i))
      # train the model using the train data
      bayes = LogisticRegression(C = i )
      bayes.fit(standard_df_train, y_train)

      # predict using the trained model
      y_pred_train = bayes.predict(standard_df_train)
      y_pred_test = bayes.predict(standard_df_test)

      # Accuracy
      acc_train = accuracy_score(y_train, y_pred_train)
      print('Accuracy of training data',acc_train)
      acc_test = accuracy_score(y_test, y_pred_test)
      print('Accuracy of testing data',acc_test)
      print('-'*50)
      print('-'*50)
# Out:
#  alpha = 0.0001
# Accuracy of training data 0.6146272855133614
# Accuracy of testing data 0.6292134831460674
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.001
# Accuracy of training data 0.6455696202531646
# Accuracy of testing data 0.6573033707865169
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.01
# Accuracy of training data 0.7834036568213784
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 0.1
# Accuracy of training data 0.8002812939521801
# Accuracy of testing data 0.7584269662921348
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 1
# Accuracy of training data 0.8073136427566807
# Accuracy of testing data 0.7471910112359551
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 10
# Accuracy of training data 0.8073136427566807
# Accuracy of testing data 0.7471910112359551
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 100
# Accuracy of training data 0.8059071729957806
# Accuracy of testing data 0.7471910112359551
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 1000
# Accuracy of training data 0.8059071729957806
# Accuracy of testing data 0.7471910112359551
# --------------------------------------------------
# --------------------------------------------------
#  alpha = 10000
# Accuracy of training data 0.8059071729957806
# Accuracy of testing data 0.7471910112359551
# --------------------------------------------------
# --------------------------------------------------

# %%
import numpy as np
feature_importance = abs(bayes.coef_[0])
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
pos
# Out:
# array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5])

# %%
abs(-2)
# Out:
# 2
